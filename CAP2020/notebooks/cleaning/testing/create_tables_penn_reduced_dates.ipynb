# %% [markdown]
# ### PACKAGES

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
from time import time
import numpy as np
from sklearn.utils import shuffle
os.chdir('C:\\Users\\A Sua\\Documents\\FIU\\CAP2020')

# %% [markdown]
# ### DEFINE FUNCTIONS

# %% [markdown]
# #### timeit wrapper

# %%
def timing(f):
    def wrap(*args):
        time1 = time()
        ret = f(*args)
        time2 = time()
        print('{:s} function took {:.3f} ms'.format(f.__name__, (time2-time1)*1000.0))

        return ret
    return wrap

# %%
@timing
def run_func():
    print('hi')
run_func()
# Out:
# hi
# run_func function took 1.048 ms

# %% [markdown]
# ### IMPORT DATA

# %%
@timing
def import_data():
    
    #converter = lambda x: pd.to_numeric(x, 'coerce')
    #df = pd.read_csv('data\\raw\\PENN_SP500_daily.csv', delim_whitespace=True, converters={1: converter}, header=None)
    df = pd.read_csv('data\\raw\\PENN_SP500_daily.csv')
    #df = shuffle(df, random_state=0)
    df = df[['date',
    'TICKER',
    'COMNAM',
    'BIDLO',
    'ASKHI',
    'PRC',
    'VOL',
    'RET',
    #'BID',
    #'ASK',
    'SHROUT',
    'OPENPRC']]

    return df
    
df = import_data()
df.columns = ['date', 'symbol', 'name', 'bidlo', 'askhi', 'price', 'vol', 'ret', 
              #'bid', 'ask', 
              'sout', 'open']
print('initial shape {}'.format(df.shape))

df.head()
# Out:
# import_data function took 29314.546 ms
# initial shape (2337279, 10)
#        date symbol         name     bidlo     askhi     price         vol  \
# 0  20000103   ORCL  ORACLE CORP  111.6250  125.1875  118.1250  24831819.0
# 1  20000104   ORCL  ORACLE CORP  105.0000  118.6250  107.6875  29568565.0
# 2  20000105   ORCL  ORACLE CORP   96.0000  106.3750  102.0000  42032160.0
# 3  20000106   ORCL  ORACLE CORP   94.6875  105.0000   96.0000  27848885.0
# 4  20000107   ORCL  ORACLE CORP   93.5625  103.5000  103.3750  23218034.0
#
#         ret       sout       open
# 0  0.054099  1423672.0  124.62500
# 1  -0.08836  1423672.0  115.50000
# 2 -0.052815  1423672.0  101.62500
# 3 -0.058824  1423672.0  100.15625
# 4  0.076823  1423672.0   95.00000

# %% [markdown]
# ### BEGIN CLEANING

# %% [markdown]
# ### DROP DUPLICATES

# %%
print('old shape {}'.format(df.shape))
df = df.drop_duplicates()
print('new shape: {}'.format(df.shape))
# Out:
# old shape (2337279, 10)
# new shape: (2337166, 10)

# %% [markdown]
# ### DROP ROWS WITH WRONG VALUES

# %%
"""MESSY DATA"""
indices_to_drop = df[df['ret']=='B'].index
df = df.drop(index=indices_to_drop)

indices_to_drop = df[df['ret']=='C'].index
df = df.drop(index=indices_to_drop)
#print('{} rows were dropped'.format(len(indices_to_drop)))

# %% [markdown]
# ### STANDARDIZE, FORMALIZE COLUMNS (make into proper datatype)

# %% [markdown]
# #### CHANGE date to DATETIME

# %%
df['date'] = pd.to_datetime(df['date'], format='%Y%m%d')#, errors='ignore')
print(df.shape)
df.head()
# Out:
# (2330557, 10)
#         date symbol         name     bidlo     askhi     price         vol  \
# 0 2000-01-03   ORCL  ORACLE CORP  111.6250  125.1875  118.1250  24831819.0
# 1 2000-01-04   ORCL  ORACLE CORP  105.0000  118.6250  107.6875  29568565.0
# 2 2000-01-05   ORCL  ORACLE CORP   96.0000  106.3750  102.0000  42032160.0
# 3 2000-01-06   ORCL  ORACLE CORP   94.6875  105.0000   96.0000  27848885.0
# 4 2000-01-07   ORCL  ORACLE CORP   93.5625  103.5000  103.3750  23218034.0
#
#         ret       sout       open
# 0  0.054099  1423672.0  124.62500
# 1  -0.08836  1423672.0  115.50000
# 2 -0.052815  1423672.0  101.62500
# 3 -0.058824  1423672.0  100.15625
# 4  0.076823  1423672.0   95.00000

# %% [markdown]
# #### CHANGE symbol, name columns to string

# %%
df['symbol'] = df['symbol'].astype(str)
df['name'] = df['name'].astype(str)

# %% [markdown]
# ### CHANGE bidlo, askhi, price, vol, ret, bid, ask, sout, open to FLOAT

# %%
df['bidlo'] = df['bidlo'].astype(float)
df['askhi'] = df['askhi'].astype(float)
df['price'] = df['price'].astype(float)
df['vol'] = df['vol'].astype(float)
df['ret'] = df['ret'].astype(float)
#df['bid'] = df['bid'].astype(float)
#df['ask'] = df['ask'].astype(float)
df['sout'] = df['sout'].astype(float)
df['open'] = df['open'].astype(float)

# %% [markdown]
# #### CREATE NEW PRIMARY KEY TO BE APPLIED TO EACH TABLE
# #### CONCATINATION BETWEEN SYMBOL AND COMPANY NAME

# %%
@timing
def create_key():
    key_list = []
    for i in range(len(df)):
        term = str(df.iloc[i, 1])
        if not term:
            value  = '0_'+df.iloc[i, 2]
            key_list.append(value)
        else:
            value = str(df.iloc[i, 1])+'_'+str(df.iloc[i, 2])
            key_list.append(value)

    return key_list

key_list = create_key()
df['key'] = key_list
del key_list

print('The final df has shape {}'.format(df.shape))
df.head()
# Out:
# create_key function took 169407.906 ms
# The final df has shape (2330557, 11)
#         date symbol         name     bidlo     askhi     price         vol  \
# 0 2000-01-03   ORCL  ORACLE CORP  111.6250  125.1875  118.1250  24831819.0
# 1 2000-01-04   ORCL  ORACLE CORP  105.0000  118.6250  107.6875  29568565.0
# 2 2000-01-05   ORCL  ORACLE CORP   96.0000  106.3750  102.0000  42032160.0
# 3 2000-01-06   ORCL  ORACLE CORP   94.6875  105.0000   96.0000  27848885.0
# 4 2000-01-07   ORCL  ORACLE CORP   93.5625  103.5000  103.3750  23218034.0
#
#         ret       sout       open               key
# 0  0.054099  1423672.0  124.62500  ORCL_ORACLE CORP
# 1 -0.088360  1423672.0  115.50000  ORCL_ORACLE CORP
# 2 -0.052815  1423672.0  101.62500  ORCL_ORACLE CORP
# 3 -0.058824  1423672.0  100.15625  ORCL_ORACLE CORP
# 4  0.076823  1423672.0   95.00000  ORCL_ORACLE CORP

# %%
oknk = pd.read_csv('data\\external\\old_key_new_key.csv')
oknk.head()
# Out:
#                      OLD_KEY        NEW_KEY
# 0  ACN_ACCENTURE LTD BERMUDA  ACN_ACCENTURE
# 1  ACN_ACCENTURE PLC IRELAND  ACN_ACCENTURE
# 2             ADBE_ADOBE INC     ADBE_ADOBE
# 3     ADBE_ADOBE SYSTEMS INC     ADBE_ADOBE
# 4       BIIB_BIOGEN IDEC INC    BIIB_BIOGEN

# %%
df_merge = pd.merge(df, oknk, left_on='key', right_on='OLD_KEY', copy=False)
df_merge = df_merge.drop_duplicates()
#df_merge.index = df_merge['NEW_KEY']
df_merge = df_merge.drop(['key'], axis=1)
df_merge.head()
# Out:
#         date symbol         name     bidlo     askhi     price         vol  \
# 0 2000-01-03   ORCL  ORACLE CORP  111.6250  125.1875  118.1250  24831819.0
# 1 2000-01-04   ORCL  ORACLE CORP  105.0000  118.6250  107.6875  29568565.0
# 2 2000-01-05   ORCL  ORACLE CORP   96.0000  106.3750  102.0000  42032160.0
# 3 2000-01-06   ORCL  ORACLE CORP   94.6875  105.0000   96.0000  27848885.0
# 4 2000-01-07   ORCL  ORACLE CORP   93.5625  103.5000  103.3750  23218034.0
#
#         ret       sout       open           OLD_KEY           NEW_KEY
# 0  0.054099  1423672.0  124.62500  ORCL_ORACLE CORP  ORCL_ORACLE CORP
# 1 -0.088360  1423672.0  115.50000  ORCL_ORACLE CORP  ORCL_ORACLE CORP
# 2 -0.052815  1423672.0  101.62500  ORCL_ORACLE CORP  ORCL_ORACLE CORP
# 3 -0.058824  1423672.0  100.15625  ORCL_ORACLE CORP  ORCL_ORACLE CORP
# 4  0.076823  1423672.0   95.00000  ORCL_ORACLE CORP  ORCL_ORACLE CORP

# %% [markdown]
# #### CREATE LIST OF KEYS

# %%
# key_list = df_name.index.unique()
# print(len(key_list))
# key_list[0]

# %% [markdown]
# #### CREATE LIST OF NEW KEYS

# %%
new_key_list = df_merge['NEW_KEY'].unique()
print(len(new_key_list))
new_key_list[0]
# Out:
# 712
# 'ORCL_ORACLE CORP'

# %%
print(df.shape)
print(df_merge.shape)
# Out:
# (2330557, 11)
# (2330561, 12)

# %% [markdown]
# ## CREATE TABLES/ENTITIES
# ###### ...
# ###### ...

# %% [markdown]
# ### NAME TABLE

# %%
df_name = df_merge[['symbol', 'name', 'NEW_KEY']]
df_name = df_name.drop_duplicates()
df_name.index = df_name['NEW_KEY']
df_name = df_name.drop('NEW_KEY', axis=1)
df_name.to_csv('data\\interim\\df_symbols_names.csv')
df_name.head()
# Out:
#                                 symbol                         name
# NEW_KEY
# ORCL_ORACLE CORP                  ORCL                  ORACLE CORP
# MSFT_MICROSOFT CORP               MSFT               MICROSOFT CORP
# TROW_T ROWE PRICE GROUP INC       TROW       T ROWE PRICE ASSOC INC
# TROW_T ROWE PRICE GROUP INC       TROW       T ROWE PRICE GROUP INC
# HON_HONEYWELL INTERNATIONAL INC    HON  HONEYWELL INTERNATIONAL INC

# %% [markdown]
# ##### CHECK THE KEYS ARE UNIQUE

# %%
num_keys = df_name.index.value_counts().sort_values(ascending=False).sum()
num_rows = df_name.shape[0]

if num_keys == num_rows:
    print("the df are the same:\n{} unique values\n{} rows of name df".format(num_keys , num_rows))
else:
    print('the df values are not the same {} vs. {}'.format(num_keys , num_rows))
    
#df_name.index.value_counts().sort_values(ascending=False)
# Out:
# the df are the same:
# 847 unique values
# 847 rows of name df

# %% [markdown]
# ## UPDATE 1/28 FILTER THE DATAFRAME 1/1/2007 - 12/31/18

# %%
print('before format: {}'.format(df_merge.shape))
df_merge = df_merge[(df_merge['date']>='2007-1-1') & (df_merge['date']<='2018-12-31')]
print('after filter: {}'.format(df_merge.shape))
df_merge.head()
# Out:
# before format: (2330561, 12)
# after filter: (1487617, 12)
#            date symbol         name    bidlo  askhi  price         vol  \
# 1759 2007-01-03   ORCL  ORACLE CORP  17.1000  17.78  17.51  52271846.0
# 1760 2007-01-04   ORCL  ORACLE CORP  17.3000  17.87  17.68  34992680.0
# 1761 2007-01-05   ORCL  ORACLE CORP  17.4400  17.76  17.64  33812092.0
# 1762 2007-01-08   ORCL  ORACLE CORP  17.4499  17.93  17.86  31018863.0
# 1763 2007-01-09   ORCL  ORACLE CORP  17.6500  17.98  17.82  31417003.0
#
#            ret       sout    open           OLD_KEY           NEW_KEY
# 1759  0.021587  5182191.0  17.215  ORCL_ORACLE CORP  ORCL_ORACLE CORP
# 1760  0.009709  5182191.0  17.550  ORCL_ORACLE CORP  ORCL_ORACLE CORP
# 1761 -0.002262  5182191.0  17.620  ORCL_ORACLE CORP  ORCL_ORACLE CORP
# 1762  0.012472  5182191.0  17.630  ORCL_ORACLE CORP  ORCL_ORACLE CORP
# 1763 -0.002240  5182191.0  17.930  ORCL_ORACLE CORP  ORCL_ORACLE CORP

# %% [markdown]
# #### CREATE LIST OF NEW KEYS

# %%
new_key_list = df_merge['NEW_KEY'].unique()
print(len(new_key_list))
new_key_list[0]
# Out:
# 592
# 'ORCL_ORACLE CORP'

# %% [markdown]
# ### PICK THE COMPANIES THAT ACTUALLY MADE IT TO 12/31/18

# %%
# reduced_new_key_list = []
# for company in new_key_list:
#     temp_df = df_merge[df_merge['NEW_KEY'] == company]
#     try:
#         temp_df[temp_df['date']=='2018-12-31']
#         reduced_new_key_list.append(company)
#     except:
#         pass

# print(len(reduced_new_key_list))
# Out:
# 592

# %%
new_key_list = df_merge[df_merge['date'] == '2018-12-31']['NEW_KEY'].unique()

# %%
# for value in new_key_list[:3]:
#     print(value)
# Out:
# ORCL_ORACLE CORP
# MSFT_MICROSOFT CORP
# TROW_T ROWE PRICE GROUP INC

# %% [markdown]
# ## CREATE THE TABLES:
# - BIDLO/BID
# - ASKHI/ASK
# - PRICE
# - VOLUME
# - RETURNS
# - OPEN PRICE
# - SHARES OUTSTANDING

# %%
# temp_list = new_key_list[:10]
# temp_list

# %% [markdown]
# ### BIDLO

# %%
@timing
def bidlo_func():

    bidlo_error = []
    df_bidlo = df_merge[['date', 'NEW_KEY', 'bidlo']]
    ########----------------#######
    df_bidlo_temp = pd.DataFrame([])
    #for symbol in list_symbol:
    for symbol in new_key_list:
    #for symbol in error_bidlo:
        try:
            df_temp = df_bidlo[df_bidlo['NEW_KEY']==symbol] ### NO _temp IN THE FILTER
            #print('setting {} date index'.format(symbol))
            df_temp.index=df_temp['date']
            #print('subsetting {} bidlo'.format(symbol))            
            df_temp = df_temp[['bidlo']]
            #print(len(df_temp))
            #print('setting {} transpose'.format(symbol))            
            df_temp = df_temp.T
            #print('changin {} index'.format(symbol))
            df_temp.index = [symbol]
            #df_temp.rename()
            #print('CONCATENATING {}'.format(symbol))
            df_bidlo_temp = pd.concat([df_bidlo_temp, df_temp], axis=0) ### TEMP
            #print('finished with {}\n'.format(symbol))
        except Exception as e:
        #except: 
            #print(symbol, e)
            bidlo_error.append(symbol)
            
    return df_bidlo_temp, bidlo_error
    
df_bidlo, error_bidlo = bidlo_func()
print(len(error_bidlo), df_bidlo.shape)
#pd.Series(error_bidlo).to_csv('data\\interim\\error_bidlo_temp.csv')
df_bidlo.head()
# Out:
# bidlo_func function took 89297.508 ms
# 12 (489, 3021)
# date                             2007-01-03  2007-01-04  2007-01-05  \
# ORCL_ORACLE CORP                      17.10       17.30       17.44
# MSFT_MICROSOFT CORP                   29.40       29.44       29.45
# TROW_T ROWE PRICE GROUP INC           45.03       45.57       45.89
# HON_HONEYWELL INTERNATIONAL INC       44.88       44.38       44.29
# ADM_ARCHER DANIELS MIDLAND CO         31.82       31.40       31.36
#
# date                             2007-01-08  2007-01-09  2007-01-10  \
# ORCL_ORACLE CORP                    17.4499       17.65     17.5499
# MSFT_MICROSOFT CORP                 29.5300       29.73     29.4300
# TROW_T ROWE PRICE GROUP INC         45.6400       46.85     46.5200
# HON_HONEYWELL INTERNATIONAL INC     44.3100       44.67     44.6200
# ADM_ARCHER DANIELS MIDLAND CO       31.3200       31.15     30.6100
#
# date                             2007-01-11  2007-01-12  2007-01-16  \
# ORCL_ORACLE CORP                    17.3500       17.28       17.26
# MSFT_MICROSOFT CORP                 29.6499       30.64       31.03
# TROW_T ROWE PRICE GROUP INC         47.3700       48.05       47.88
# HON_HONEYWELL INTERNATIONAL INC     45.1600       45.04       45.22
# ADM_ARCHER DANIELS MIDLAND CO       30.2000       30.94       30.46
#
# date                             2007-01-17  ...  2018-12-17  2018-12-18  \
# ORCL_ORACLE CORP                     17.279  ...       45.53       45.44
# MSFT_MICROSOFT CORP                  31.010  ...      101.71      102.52
# TROW_T ROWE PRICE GROUP INC          48.060  ...       90.69       90.33
# HON_HONEYWELL INTERNATIONAL INC      45.320  ...      133.58      134.38
# ADM_ARCHER DANIELS MIDLAND CO        30.710  ...       43.16       42.61
#
# date                             2018-12-19  2018-12-20  2018-12-21  \
# ORCL_ORACLE CORP                   45.75000       45.48      43.860
# MSFT_MICROSOFT CORP               101.35000       98.78      97.460
# TROW_T ROWE PRICE GROUP INC        88.07000       86.91      86.390
# HON_HONEYWELL INTERNATIONAL INC   132.14999      129.37     129.330
# ADM_ARCHER DANIELS MIDLAND CO      42.10000       40.66      40.525
#
# date                             2018-12-24  2018-12-26  2018-12-27  \
# ORCL_ORACLE CORP                      42.68       42.40     43.4600
# MSFT_MICROSOFT CORP                   93.98       93.96     96.4000
# TROW_T ROWE PRICE GROUP INC           84.79       84.59     88.0000
# HON_HONEYWELL INTERNATIONAL INC      124.63      123.48    126.8438
# ADM_ARCHER DANIELS MIDLAND CO         39.42       39.16     39.7800
#
# date                             2018-12-28  2018-12-31
# ORCL_ORACLE CORP                      44.74     44.8400
# MSFT_MICROSOFT CORP                   99.52    100.4400
# TROW_T ROWE PRICE GROUP INC           90.68     91.3300
# HON_HONEYWELL INTERNATIONAL INC      130.25    130.4700
# ADM_ARCHER DANIELS MIDLAND CO         40.50     40.5038
#
# [5 rows x 3021 columns]

# %% [markdown]
# #### Error Note
# - There are Duplicate dates for each stock in the error dataframe

# %% [markdown]
# #### Take LOWEST BIDLO value for each of the duplicated dates
# - Same with BID

# %%
df_error_bidlo = pd.DataFrame([])

for error_comapny in error_bidlo:
    temp_df = df_merge[df_merge['NEW_KEY']==error_comapny]
    temp_df = temp_df[['NEW_KEY', 'date', 'bidlo']]
    df_error_bidlo = pd.concat([df_error_bidlo, temp_df])

df_error_bidlo = df_error_bidlo.sort_values(['NEW_KEY', 'date'])

print('shape before drop: {}'.format(df_error_bidlo.shape))
df_error_bidlo = df_error_bidlo.groupby(['NEW_KEY', 'date'], sort=False).min()
print('shape after the drop {}'.format(df_error_bidlo.shape))
df_error_bidlo.head()

##########---------------###-------########------------#########

print('before adding error dataframes: {}'.format(df_bidlo.shape))

for symbol in error_bidlo:
    df_temp = df_error_bidlo.loc[symbol] ### NO _temp IN THE FILTER
    df_temp = df_temp.T
    df_temp.index = [symbol]
    df_bidlo = pd.concat([df_bidlo, df_temp], axis=0) ### TEMP
    
print('after adding error dataframes: {}'.format(df_bidlo.shape))
df_bidlo.head()
# Out:
# shape before drop: (51843, 3)
# shape after the drop (35285, 1)
# before adding error dataframes: (489, 3021)
# after adding error dataframes: (501, 3021)
# date                             2007-01-03  2007-01-04  2007-01-05  \
# ORCL_ORACLE CORP                      17.10       17.30       17.44
# MSFT_MICROSOFT CORP                   29.40       29.44       29.45
# TROW_T ROWE PRICE GROUP INC           45.03       45.57       45.89
# HON_HONEYWELL INTERNATIONAL INC       44.88       44.38       44.29
# ADM_ARCHER DANIELS MIDLAND CO         31.82       31.40       31.36
#
# date                             2007-01-08  2007-01-09  2007-01-10  \
# ORCL_ORACLE CORP                    17.4499       17.65     17.5499
# MSFT_MICROSOFT CORP                 29.5300       29.73     29.4300
# TROW_T ROWE PRICE GROUP INC         45.6400       46.85     46.5200
# HON_HONEYWELL INTERNATIONAL INC     44.3100       44.67     44.6200
# ADM_ARCHER DANIELS MIDLAND CO       31.3200       31.15     30.6100
#
# date                             2007-01-11  2007-01-12  2007-01-16  \
# ORCL_ORACLE CORP                    17.3500       17.28       17.26
# MSFT_MICROSOFT CORP                 29.6499       30.64       31.03
# TROW_T ROWE PRICE GROUP INC         47.3700       48.05       47.88
# HON_HONEYWELL INTERNATIONAL INC     45.1600       45.04       45.22
# ADM_ARCHER DANIELS MIDLAND CO       30.2000       30.94       30.46
#
# date                             2007-01-17  ...  2018-12-17  2018-12-18  \
# ORCL_ORACLE CORP                     17.279  ...       45.53       45.44
# MSFT_MICROSOFT CORP                  31.010  ...      101.71      102.52
# TROW_T ROWE PRICE GROUP INC          48.060  ...       90.69       90.33
# HON_HONEYWELL INTERNATIONAL INC      45.320  ...      133.58      134.38
# ADM_ARCHER DANIELS MIDLAND CO        30.710  ...       43.16       42.61
#
# date                             2018-12-19  2018-12-20  2018-12-21  \
# ORCL_ORACLE CORP                   45.75000       45.48      43.860
# MSFT_MICROSOFT CORP               101.35000       98.78      97.460
# TROW_T ROWE PRICE GROUP INC        88.07000       86.91      86.390
# HON_HONEYWELL INTERNATIONAL INC   132.14999      129.37     129.330
# ADM_ARCHER DANIELS MIDLAND CO      42.10000       40.66      40.525
#
# date                             2018-12-24  2018-12-26  2018-12-27  \
# ORCL_ORACLE CORP                      42.68       42.40     43.4600
# MSFT_MICROSOFT CORP                   93.98       93.96     96.4000
# TROW_T ROWE PRICE GROUP INC           84.79       84.59     88.0000
# HON_HONEYWELL INTERNATIONAL INC      124.63      123.48    126.8438
# ADM_ARCHER DANIELS MIDLAND CO         39.42       39.16     39.7800
#
# date                             2018-12-28  2018-12-31
# ORCL_ORACLE CORP                      44.74     44.8400
# MSFT_MICROSOFT CORP                   99.52    100.4400
# TROW_T ROWE PRICE GROUP INC           90.68     91.3300
# HON_HONEYWELL INTERNATIONAL INC      130.25    130.4700
# ADM_ARCHER DANIELS MIDLAND CO         40.50     40.5038
#
# [5 rows x 3021 columns]

# %% [markdown]
# ### ASKHI TABLE

# %%
@timing
def askhi_func():
    error_askhi = []
    df_askhi = df_merge[['date', 'NEW_KEY', 'askhi']]
    df_askhi_temp = pd.DataFrame([])
    
    for symbol in new_key_list:
        try:
            df_temp = df_askhi[df_askhi['NEW_KEY']==symbol]
            df_temp.index=df_temp['date']
            df_temp = df_temp[['askhi']]
            df_temp = df_temp.T
            df_temp.index = [symbol]
            df_askhi_temp = pd.concat([df_askhi_temp, df_temp], axis=0)

        #except:
        except Exception as e:
            #print(symbol, e)
            error_askhi.append(symbol)
    return df_askhi_temp, error_askhi

df_askhi, error_askhi = askhi_func()
print(len(error_askhi), df_askhi.shape)
#pd.Series(error_askhi).to_csv('..\data\\error_askhi.csv')
#df_askhi.head(2)
# Out:
# askhi_func function took 88250.162 ms
# 12 (489, 3021)

# %% [markdown]
# ### Take the error dataframe and filter out the highest ASKHI value for each of the days of each of the companies
# - Same with ASK

# %%
df_error_askhi = pd.DataFrame([])

for error_comapny in error_askhi:
    temp_df = df_merge[df_merge['NEW_KEY']==error_comapny]
    temp_df = temp_df[['NEW_KEY', 'date', 'askhi']]
    df_error_askhi = pd.concat([df_error_askhi, temp_df])

df_error_askhi = df_error_askhi.sort_values(['NEW_KEY', 'date'])

print('shape before drop: {}'.format(df_error_askhi.shape))
"""TAKE THE MAX ASKHI"""
df_error_askhi = df_error_askhi.groupby(['NEW_KEY', 'date'], sort=False).max()
print('shape after the drop {}'.format(df_error_askhi.shape))
#df_error_askhi.head()

#######----------#############-------------########
print('before adding error dataframes: {}'.format(df_askhi.shape))

for symbol in error_askhi:
    df_temp = df_error_askhi.loc[symbol] ### NO _temp IN THE FILTER
    df_temp = df_temp.T
    df_temp.index = [symbol]
    df_askhi = pd.concat([df_askhi, df_temp], axis=0) ### TEMP
    
print('after adding error dataframes: {}'.format(df_askhi.shape))
df_askhi.head()
# Out:
# shape before drop: (51843, 3)
# shape after the drop (35285, 1)
# before adding error dataframes: (489, 3021)
# after adding error dataframes: (501, 3021)
# date                             2007-01-03  2007-01-04  2007-01-05  \
# ORCL_ORACLE CORP                      17.78       17.87       17.76
# MSFT_MICROSOFT CORP                   30.25       29.97       29.75
# TROW_T ROWE PRICE GROUP INC           46.25       46.32       46.38
# HON_HONEYWELL INTERNATIONAL INC       45.69       45.21       45.11
# ADM_ARCHER DANIELS MIDLAND CO         32.76       32.09       31.88
#
# date                             2007-01-08  2007-01-09  2007-01-10  \
# ORCL_ORACLE CORP                      17.93       17.98       17.80
# MSFT_MICROSOFT CORP                   30.10       30.18       29.89
# TROW_T ROWE PRICE GROUP INC           47.01       47.54       47.44
# HON_HONEYWELL INTERNATIONAL INC       45.05       45.33       45.09
# ADM_ARCHER DANIELS MIDLAND CO         32.05       31.95       31.47
#
# date                             2007-01-11  2007-01-12  2007-01-16  \
# ORCL_ORACLE CORP                      17.81      17.550     17.4801
# MSFT_MICROSOFT CORP                   30.75      31.390     31.4500
# TROW_T ROWE PRICE GROUP INC           48.37      48.608     48.8200
# HON_HONEYWELL INTERNATIONAL INC       45.99      45.700     45.7100
# ADM_ARCHER DANIELS MIDLAND CO         32.00      32.440     31.3100
#
# date                             2007-01-17  ...  2018-12-17  2018-12-18  \
# ORCL_ORACLE CORP                      17.71  ...    47.23000    48.34000
# MSFT_MICROSOFT CORP                   31.44  ...   105.80000   104.51000
# TROW_T ROWE PRICE GROUP INC           48.56  ...    93.32520    92.64000
# HON_HONEYWELL INTERNATIONAL INC       45.90  ...   137.17999   136.75999
# ADM_ARCHER DANIELS MIDLAND CO         31.38  ...    44.49000    43.99000
#
# date                             2018-12-19  2018-12-20  2018-12-21  \
# ORCL_ORACLE CORP                   47.44000       46.95       46.21
# MSFT_MICROSOFT CORP               106.88000      104.31      103.00
# TROW_T ROWE PRICE GROUP INC        92.12000       88.99       90.33
# HON_HONEYWELL INTERNATIONAL INC   137.75999      133.62      132.45
# ADM_ARCHER DANIELS MIDLAND CO      43.56000       42.25       41.77
#
# date                             2018-12-24  2018-12-26  2018-12-27  \
# ORCL_ORACLE CORP                   43.82000    44.61000       45.09
# MSFT_MICROSOFT CORP                97.97000   100.69000      101.19
# TROW_T ROWE PRICE GROUP INC        87.53250    89.73000       91.37
# HON_HONEYWELL INTERNATIONAL INC   128.99001   129.60001      131.63
# ADM_ARCHER DANIELS MIDLAND CO      40.70000    40.69000       40.97
#
# date                             2018-12-28  2018-12-31
# ORCL_ORACLE CORP                   45.76500       45.50
# MSFT_MICROSOFT CORP               102.41000      102.40
# TROW_T ROWE PRICE GROUP INC        92.42000       92.69
# HON_HONEYWELL INTERNATIONAL INC   133.07001      132.16
# ADM_ARCHER DANIELS MIDLAND CO      41.49000       41.04
#
# [5 rows x 3021 columns]

# %% [markdown]
# ### PRICE TABLE

# %%
@timing
def price_func():
    error_price = []
    
    df_price = df_merge[['date', 'NEW_KEY', 'price']]
    ########----------------#######
    df_price_temp = pd.DataFrame([])
    for symbol in new_key_list:
        try:
            df_temp = df_price[df_price['NEW_KEY']==symbol] ### NO _temp IN THE FILTER
            df_temp.index=df_temp['date']
            df_temp = df_temp[['price']]
            df_temp = df_temp.T
            df_temp.index = [symbol]
            #df_temp.rename()
            df_price_temp = pd.concat([df_price_temp, df_temp], axis=0) ### TEMP
        except Exception as e:
            #print(symbol, e)
            error_price.append(symbol)
    return df_price_temp, error_price

df_price, error_price = price_func()
print(len(error_price), df_price.shape)
#pd.Series(error_price).to_csv('..\data\\error_price.csv')
#df_price.head(2)
# Out:
# price_func function took 89690.079 ms
# 12 (489, 3021)

# %% [markdown]
# ##### take MAX price

# %%
df_error_price = pd.DataFrame([])

for error_comapny in error_price:
    temp_df = df_merge[df_merge['NEW_KEY']==error_comapny]
    temp_df = temp_df[['NEW_KEY', 'date', 'price']]
    df_error_price = pd.concat([df_error_price, temp_df])

df_error_price = df_error_price.sort_values(['NEW_KEY', 'date'])

print('shape before drop: {}'.format(df_error_price.shape))
"""TAKE THE MAX PRICE"""
df_error_price = df_error_price.groupby(['NEW_KEY', 'date'], sort=False).max()
print('shape after the drop {}'.format(df_error_price.shape))
#df_error_askhi.head()

#######----------#############-------------########
print('before adding error dataframes: {}'.format(df_price.shape))

for symbol in error_askhi:
    df_temp = df_error_price.loc[symbol] ### NO _temp IN THE FILTER
    df_temp = df_temp.T
    df_temp.index = [symbol]
    df_price = pd.concat([df_price, df_temp], axis=0) ### TEMP

    
"""DROP DUPLICATES"""
df_price = df_price.drop_duplicates()    
print('after adding error dataframes: {}'.format(df_price.shape))
df_price.head()
# Out:
# shape before drop: (51843, 3)
# shape after the drop (35285, 1)
# before adding error dataframes: (489, 3021)
# after adding error dataframes: (501, 3021)
# date                             2007-01-03  2007-01-04  2007-01-05  \
# ORCL_ORACLE CORP                      17.51       17.68       17.64
# MSFT_MICROSOFT CORP                   29.86       29.81       29.64
# TROW_T ROWE PRICE GROUP INC           45.75       46.15       46.06
# HON_HONEYWELL INTERNATIONAL INC       45.10       45.08       44.65
# ADM_ARCHER DANIELS MIDLAND CO         32.06       31.88       31.83
#
# date                             2007-01-08  2007-01-09  2007-01-10  \
# ORCL_ORACLE CORP                      17.86       17.82       17.77
# MSFT_MICROSOFT CORP                   29.93       29.96       29.66
# TROW_T ROWE PRICE GROUP INC           46.90       47.09       47.36
# HON_HONEYWELL INTERNATIONAL INC       44.92       45.24       44.96
# ADM_ARCHER DANIELS MIDLAND CO         31.99       31.21       30.94
#
# date                             2007-01-11  2007-01-12  2007-01-16  \
# ORCL_ORACLE CORP                      17.39       17.50       17.30
# MSFT_MICROSOFT CORP                   30.70       31.21       31.16
# TROW_T ROWE PRICE GROUP INC           48.29       48.56       48.06
# HON_HONEYWELL INTERNATIONAL INC       45.71       45.56       45.62
# ADM_ARCHER DANIELS MIDLAND CO         31.68       30.96       31.02
#
# date                             2007-01-17  ...  2018-12-17  2018-12-18  \
# ORCL_ORACLE CORP                      17.52  ...       45.73    45.85000
# MSFT_MICROSOFT CORP                   31.10  ...      102.89   103.97000
# TROW_T ROWE PRICE GROUP INC           48.25  ...       91.03    90.80000
# HON_HONEYWELL INTERNATIONAL INC       45.54  ...      134.38   135.17999
# ADM_ARCHER DANIELS MIDLAND CO         31.18  ...       43.38    42.84000
#
# date                             2018-12-19  2018-12-20  2018-12-21  \
# ORCL_ORACLE CORP                   46.45000       46.24       44.00
# MSFT_MICROSOFT CORP               103.69000      101.51       98.23
# TROW_T ROWE PRICE GROUP INC        88.41000       87.30       86.78
# HON_HONEYWELL INTERNATIONAL INC   133.25999      130.67      129.44
# ADM_ARCHER DANIELS MIDLAND CO      42.40000       41.23       40.80
#
# date                             2018-12-24  2018-12-26  2018-12-27  \
# ORCL_ORACLE CORP                      42.69    44.59000    44.97000
# MSFT_MICROSOFT CORP                   94.13   100.56000   101.18000
# TROW_T ROWE PRICE GROUP INC           84.95    89.65000    91.31000
# HON_HONEYWELL INTERNATIONAL INC      124.83   129.57001   131.57001
# ADM_ARCHER DANIELS MIDLAND CO         39.62    40.67000    40.96000
#
# date                             2018-12-28  2018-12-31
# ORCL_ORACLE CORP                   44.82000       45.15
# MSFT_MICROSOFT CORP               100.39000      101.57
# TROW_T ROWE PRICE GROUP INC        91.34000       92.32
# HON_HONEYWELL INTERNATIONAL INC   130.75999      132.12
# ADM_ARCHER DANIELS MIDLAND CO      40.78000       40.97
#
# [5 rows x 3021 columns]

# %% [markdown]
# ### VOLUME TABLE

# %%
@timing
def volume_func():
    error_volume = []
    
    df_volume = df_merge[['date', 'NEW_KEY', 'vol']]
    ########----------------#######
    df_volume_temp = pd.DataFrame([])
    for symbol in new_key_list:
        try:            
            df_temp = df_volume[df_volume['NEW_KEY']==symbol] ### NO _temp IN THE FILTER
            df_temp.index=df_temp['date']
            df_temp = df_temp[['vol']]
            df_temp = df_temp.T
            df_temp.index = [symbol]
            #df_temp.rename()
            df_volume_temp = pd.concat([df_volume_temp, df_temp], axis=0) ### TEMP    
        except:
            error_volume.append(symbol)
    return df_volume_temp, error_volume

df_volume, error_volume = volume_func()
print(len(error_volume), df_volume.shape)
#pd.Series(error_volume).to_csv('..\data\\error_volume.csv')
#df_volume.head(2)
# Out:
# volume_func function took 96633.505 ms
# 12 (489, 3021)

# %% [markdown]
# ##### take MAX volume

# %%
df_error_volume = pd.DataFrame([])

for error_comapny in error_volume:
    temp_df = df_merge[df_merge['NEW_KEY']==error_comapny]
    temp_df = temp_df[['NEW_KEY', 'date', 'vol']]
    df_error_volume = pd.concat([df_error_volume, temp_df])

df_error_volume = df_error_volume.sort_values(['NEW_KEY', 'date'])

print('shape before drop: {}'.format(df_error_volume.shape))
"""TAKE THE MAX PRICE"""
df_error_volume = df_error_volume.groupby(['NEW_KEY', 'date'], sort=False).max()
print('shape after the drop {}'.format(df_error_volume.shape))
#df_error_askhi.head()

#######----------#############-------------########
print('before adding error dataframes: {}'.format(df_volume.shape))

for symbol in error_volume:
    df_temp = df_error_volume.loc[symbol] ### NO _temp IN THE FILTER
    df_temp = df_temp.T
    df_temp.index = [symbol]
    df_volume = pd.concat([df_volume, df_temp], axis=0) ### TEMP

    
"""DROP DUPLICATES"""
df_volume = df_volume.drop_duplicates()    
print('after adding error dataframes: {}'.format(df_volume.shape))
df_volume.head()
# Out:
# shape before drop: (51843, 3)
# shape after the drop (35285, 1)
# before adding error dataframes: (489, 3021)
# after adding error dataframes: (501, 3021)
# date                             2007-01-03  2007-01-04  2007-01-05  \
# ORCL_ORACLE CORP                 52271846.0  34992680.0  33812092.0
# MSFT_MICROSOFT CORP              77630458.0  46650955.0  44681937.0
# TROW_T ROWE PRICE GROUP INC       2605194.0   1598889.0   1718799.0
# HON_HONEYWELL INTERNATIONAL INC   3505100.0   2630200.0   3035100.0
# ADM_ARCHER DANIELS MIDLAND CO     7380900.0   4442000.0   5798200.0
#
# date                             2007-01-08  2007-01-09  2007-01-10  \
# ORCL_ORACLE CORP                 31018863.0  31417003.0  27822425.0
# MSFT_MICROSOFT CORP              52021978.0  44708046.0  56867092.0
# TROW_T ROWE PRICE GROUP INC       1275148.0   1410212.0   1048077.0
# HON_HONEYWELL INTERNATIONAL INC   2589100.0   3043900.0   2320200.0
# ADM_ARCHER DANIELS MIDLAND CO     4892600.0   5121500.0   7781800.0
#
# date                             2007-01-11   2007-01-12  2007-01-16  \
# ORCL_ORACLE CORP                 65590483.0   42526442.0  35744443.0
# MSFT_MICROSOFT CORP              99520582.0  104312728.0  62442064.0
# TROW_T ROWE PRICE GROUP INC       1092509.0     756835.0   1077489.0
# HON_HONEYWELL INTERNATIONAL INC   3039900.0    2663900.0   2355800.0
# ADM_ARCHER DANIELS MIDLAND CO     6887100.0    7697200.0   7004000.0
#
# date                             2007-01-17  ...  2018-12-17  2018-12-18  \
# ORCL_ORACLE CORP                 32818913.0  ...  30441145.0  42855600.0
# MSFT_MICROSOFT CORP              60649602.0  ...  56956564.0  49417797.0
# TROW_T ROWE PRICE GROUP INC       1305884.0  ...   1959973.0   1804473.0
# HON_HONEYWELL INTERNATIONAL INC   2710400.0  ...   3133214.0   2637752.0
# ADM_ARCHER DANIELS MIDLAND CO     5488600.0  ...   3286593.0   3522154.0
#
# date                             2018-12-19  2018-12-20   2018-12-21  \
# ORCL_ORACLE CORP                 34397250.0  35165179.0   58768410.0
# MSFT_MICROSOFT CORP              68187880.0  70334184.0  111239770.0
# TROW_T ROWE PRICE GROUP INC       1863185.0   2156700.0    4232675.0
# HON_HONEYWELL INTERNATIONAL INC   3868924.0   4518936.0    6903728.0
# ADM_ARCHER DANIELS MIDLAND CO     3124806.0   5450046.0    8213689.0
#
# date                             2018-12-24  2018-12-26  2018-12-27  \
# ORCL_ORACLE CORP                 17230381.0  21428929.0  19048702.0
# MSFT_MICROSOFT CORP              43935112.0  51627193.0  49495409.0
# TROW_T ROWE PRICE GROUP INC       1005519.0   1587486.0   1290839.0
# HON_HONEYWELL INTERNATIONAL INC   2838791.0   3440398.0   3249638.0
# ADM_ARCHER DANIELS MIDLAND CO     2541051.0   3380531.0   3809906.0
#
# date                             2018-12-28  2018-12-31
# ORCL_ORACLE CORP                 39141279.0  14932651.0
# MSFT_MICROSOFT CORP              38162485.0  33173365.0
# TROW_T ROWE PRICE GROUP INC       1093473.0   1449392.0
# HON_HONEYWELL INTERNATIONAL INC   2759324.0   2199898.0
# ADM_ARCHER DANIELS MIDLAND CO     3046536.0   2718177.0
#
# [5 rows x 3021 columns]

# %% [markdown]
# ### RETURNS TABLE

# %%
@timing
def returns_func():
    error_returns = []
    df_return = df_merge[['date', 'NEW_KEY', 'ret']]
    ########----------------#######
    df_return_temp = pd.DataFrame([])
    for symbol in new_key_list:
        try:
            df_temp = df_return[df_return['NEW_KEY']==symbol] ### NO _temp IN THE FILTER
            df_temp.index=df_temp['date']
            df_temp = df_temp[['ret']]
            df_temp = df_temp.T
            df_temp.index = [symbol]
            #df_temp.rename()
            df_return_temp = pd.concat([df_return_temp, df_temp], axis=0) ### TEMP
        except:
            error_returns.append(symbol)
    return df_return_temp, error_returns

df_returns, error_returns = returns_func()
print(len(error_returns), df_returns.shape)
#pd.Series(error_returns).to_csv('..\data\\error_returns.csv')
#df_returns.head(2)
# Out:
# returns_func function took 90270.190 ms
# 12 (489, 3021)

# %%
#error_returns

# %% [markdown]
# ##### take max RETUNRS

# %%
df_error_returns = pd.DataFrame([])

for error_comapny in error_returns:
    temp_df = df_merge[df_merge['NEW_KEY']==error_comapny]
    temp_df = temp_df[['NEW_KEY', 'date', 'ret']]
    df_error_returns = pd.concat([df_error_returns, temp_df])

df_error_returns = df_error_returns.sort_values(['NEW_KEY', 'date'])

print('shape before drop: {}'.format(df_error_returns.shape))
"""TAKE THE MAX PRICE"""
df_error_returns = df_error_returns.groupby(['NEW_KEY', 'date'], sort=False).max()
print('shape after the drop {}'.format(df_error_returns.shape))
#df_error_askhi.head()

#######----------#############-------------########
print('before adding error dataframes: {}'.format(df_returns.shape))

for symbol in error_returns:
    df_temp = df_error_returns.loc[symbol] ### NO _temp IN THE FILTER
    df_temp = df_temp.T
    df_temp.index = [symbol]
    df_returns = pd.concat([df_returns, df_temp], axis=0) ### TEMP

    
"""DROP DUPLICATES"""
df_returns = df_returns.drop_duplicates()    
print('after adding error dataframes: {}'.format(df_returns.shape))
df_returns.head()
# Out:
# shape before drop: (51843, 3)
# shape after the drop (35285, 1)
# before adding error dataframes: (489, 3021)
# after adding error dataframes: (501, 3021)
# date                             2007-01-03  2007-01-04  2007-01-05  \
# ORCL_ORACLE CORP                   0.021587    0.009709   -0.002262
# MSFT_MICROSOFT CORP                0.000000   -0.001675   -0.005703
# TROW_T ROWE PRICE GROUP INC        0.045236    0.008743   -0.001950
# HON_HONEYWELL INTERNATIONAL INC   -0.003095   -0.000443   -0.009539
# ADM_ARCHER DANIELS MIDLAND CO      0.003129   -0.005615   -0.001568
#
# date                             2007-01-08  2007-01-09  2007-01-10  \
# ORCL_ORACLE CORP                   0.012472   -0.002240   -0.002806
# MSFT_MICROSOFT CORP                0.009784    0.001002   -0.010013
# TROW_T ROWE PRICE GROUP INC        0.018237    0.004051    0.005734
# HON_HONEYWELL INTERNATIONAL INC    0.006047    0.007124   -0.006189
# ADM_ARCHER DANIELS MIDLAND CO      0.005027   -0.024383   -0.008651
#
# date                             2007-01-11  2007-01-12  2007-01-16  \
# ORCL_ORACLE CORP                  -0.021384    0.006326   -0.011429
# MSFT_MICROSOFT CORP                0.035064    0.016612   -0.001602
# TROW_T ROWE PRICE GROUP INC        0.019637    0.005591   -0.010297
# HON_HONEYWELL INTERNATIONAL INC    0.016681   -0.003282    0.001317
# ADM_ARCHER DANIELS MIDLAND CO      0.023917   -0.022727    0.001938
#
# date                             2007-01-17  ...  2018-12-17  2018-12-18  \
# ORCL_ORACLE CORP                   0.012717  ...   -0.018670    0.002624
# MSFT_MICROSOFT CORP               -0.001926  ...   -0.029614    0.010497
# TROW_T ROWE PRICE GROUP INC        0.003953  ...   -0.010221   -0.002527
# HON_HONEYWELL INTERNATIONAL INC   -0.001754  ...   -0.015098    0.005953
# ADM_ARCHER DANIELS MIDLAND CO      0.005158  ...   -0.027572   -0.012448
#
# date                             2018-12-19  2018-12-20  2018-12-21  \
# ORCL_ORACLE CORP                   0.013086   -0.004521   -0.048443
# MSFT_MICROSOFT CORP               -0.002693   -0.021024   -0.032312
# TROW_T ROWE PRICE GROUP INC       -0.026322   -0.012555   -0.005957
# HON_HONEYWELL INTERNATIONAL INC   -0.014203   -0.019436   -0.009413
# ADM_ARCHER DANIELS MIDLAND CO     -0.010271   -0.027594   -0.010429
#
# date                             2018-12-24  2018-12-26  2018-12-27  \
# ORCL_ORACLE CORP                  -0.029773    0.044507    0.008522
# MSFT_MICROSOFT CORP               -0.041739    0.068310    0.006166
# TROW_T ROWE PRICE GROUP INC       -0.021088    0.055327    0.018516
# HON_HONEYWELL INTERNATIONAL INC   -0.035615    0.037972    0.015436
# ADM_ARCHER DANIELS MIDLAND CO     -0.028922    0.026502    0.007131
#
# date                             2018-12-28  2018-12-31
# ORCL_ORACLE CORP                  -0.003336    0.007363
# MSFT_MICROSOFT CORP               -0.007808    0.011754
# TROW_T ROWE PRICE GROUP INC        0.000329    0.010729
# HON_HONEYWELL INTERNATIONAL INC   -0.006157    0.010401
# ADM_ARCHER DANIELS MIDLAND CO     -0.004395    0.004659
#
# [5 rows x 3021 columns]

# %%
# df_returns.to_csv('data\\external\\df_returns_check.csv')

# %% [markdown]
# ### 5 best trading days in Dow since 1/1/2007 (~systemic risk)

# %%
# best_days = pd.to_datetime(['10/13/2008',
# '10/28/2008',
# '3/23/2009',
# '11/13/2008',
# '11/21/2008',
# '12/26/2018',
# '11/30/2011',
# '8/26/2015',
# '3/26/2018',
# '11/28/2018',
# '2/6/2018',
# '10/16/2018',
# '11/7/2018'])

# %%
#pd.qcut(df_returns[day], q=[0, .25, .5, .75, 1.], precision=3)

# %%
# df_returns['2008-10-13'].sort_values(ascending=False)

# %%
# for day in best_days:
#     print('day')
#     print(pd.qcut(df_returns[day], q=[0, .25, .5, .75, 1.], precision=3).value_counts())
#     print('\n\n')

# %% [markdown]
# ### 5 worst trading days in Dow since 1/1/2018 (~systemic risk)

# %%
# worst_days = pd.to_datetime(
# ['10/15/2008',
# '12/1/2008',
# '10/9/2008',
# '9/29/2008',
# '8/8/2011',
# '2/5/2018',
# '2/8/2018',
# '6/24/2016',
# '10/10/2018',
# '12/4/2018',
# '3/22/2018',
# '12/24/2018',
# '2/2/2018'])

# %%
# for day in worst_days:
#     print('day')
#     print(pd.qcut(df_returns[day], q=[0, .25, .5, .75, 1.], precision=3).value_counts())
#     print('\n\n')

# %% [markdown]
# ### SHARES OUTSTANDING TABLE

# %%
@timing
def shares_out_func():
    error_shares_out = []
    df_shares_out = df_merge[['date', 'NEW_KEY', 'sout']]
    ########----------------#######
    df_shares_out_temp = pd.DataFrame([])
    for symbol in new_key_list:
        try:
            df_temp = df_shares_out[df_shares_out['NEW_KEY']==symbol] ### NO _temp IN THE FILTER
            df_temp.index=df_temp['date']
            df_temp = df_temp[['sout']] 
            df_temp = df_temp.T
            df_temp.index = [symbol]
            #df_temp.rename()
            df_shares_out_temp = pd.concat([df_shares_out_temp, df_temp], axis=0) ### TEMP    
        except:
            error_shares_out.append(symbol)
    return df_shares_out_temp, error_shares_out

df_shares_out, error_shares_out = shares_out_func()
print(len(error_shares_out), df_shares_out.shape)
#pd.Series(error_shares_out).to_csv('..\data\\error_shares_out.csv')
#df_shares_out.head(2)
# Out:
# shares_out_func function took 89469.805 ms
# 12 (489, 3021)

# %% [markdown]
# ### take MAX shares outstanding

# %%
df_error_shares_out = pd.DataFrame([])

for error_comapny in error_returns:
    temp_df = df_merge[df_merge['NEW_KEY']==error_comapny]
    temp_df = temp_df[['NEW_KEY', 'date', 'sout']]
    df_error_shares_out = pd.concat([df_error_shares_out, temp_df])

df_error_shares_out = df_error_shares_out.sort_values(['NEW_KEY', 'date'])

print('shape before drop: {}'.format(df_error_shares_out.shape))
"""TAKE THE MAX PRICE"""
df_error_shares_out = df_error_shares_out.groupby(['NEW_KEY', 'date'], sort=False).max()
print('shape after the drop {}'.format(df_error_shares_out.shape))
#df_error_askhi.head()

#######----------#############-------------########
print('before adding error dataframes: {}'.format(df_shares_out.shape))

for symbol in error_returns:
    df_temp = df_error_shares_out.loc[symbol] ### NO _temp IN THE FILTER
    df_temp = df_temp.T
    df_temp.index = [symbol]
    df_shares_out = pd.concat([df_shares_out, df_temp], axis=0) ### TEMP

    
"""DROP DUPLICATES"""
df_shares_out = df_shares_out.drop_duplicates()    
print('after adding error dataframes: {}'.format(df_shares_out.shape))
df_shares_out.head()
# Out:
# shape before drop: (51843, 3)
# shape after the drop (35285, 1)
# before adding error dataframes: (489, 3021)
# after adding error dataframes: (501, 3021)
# date                             2007-01-03  2007-01-04  2007-01-05  \
# ORCL_ORACLE CORP                  5182191.0   5182191.0   5182191.0
# MSFT_MICROSOFT CORP               9777000.0   9777000.0   9777000.0
# TROW_T ROWE PRICE GROUP INC        264960.0    264960.0    264960.0
# HON_HONEYWELL INTERNATIONAL INC    816510.0    816510.0    816510.0
# ADM_ARCHER DANIELS MIDLAND CO      657246.0    657246.0    657246.0
#
# date                             2007-01-08  2007-01-09  2007-01-10  \
# ORCL_ORACLE CORP                  5182191.0   5182191.0   5182191.0
# MSFT_MICROSOFT CORP               9777000.0   9777000.0   9777000.0
# TROW_T ROWE PRICE GROUP INC        264960.0    264960.0    264960.0
# HON_HONEYWELL INTERNATIONAL INC    816510.0    816510.0    816510.0
# ADM_ARCHER DANIELS MIDLAND CO      657246.0    657246.0    657246.0
#
# date                             2007-01-11  2007-01-12  2007-01-16  \
# ORCL_ORACLE CORP                  5182191.0   5182191.0   5182191.0
# MSFT_MICROSOFT CORP               9777000.0   9777000.0   9777000.0
# TROW_T ROWE PRICE GROUP INC        264960.0    264960.0    264960.0
# HON_HONEYWELL INTERNATIONAL INC    816510.0    816510.0    816510.0
# ADM_ARCHER DANIELS MIDLAND CO      657246.0    657246.0    657246.0
#
# date                             2007-01-17  ...  2018-12-17  2018-12-18  \
# ORCL_ORACLE CORP                  5182191.0  ...   3787960.0   3787960.0
# MSFT_MICROSOFT CORP               9777000.0  ...   7676219.0   7676219.0
# TROW_T ROWE PRICE GROUP INC        264960.0  ...    240655.0    240655.0
# HON_HONEYWELL INTERNATIONAL INC    816510.0  ...    740288.0    740288.0
# ADM_ARCHER DANIELS MIDLAND CO      657246.0  ...    560644.0    560644.0
#
# date                             2018-12-19  2018-12-20  2018-12-21  \
# ORCL_ORACLE CORP                  3787960.0   3787960.0   3787960.0
# MSFT_MICROSOFT CORP               7676219.0   7676219.0   7676219.0
# TROW_T ROWE PRICE GROUP INC        240655.0    240655.0    240655.0
# HON_HONEYWELL INTERNATIONAL INC    740288.0    740288.0    740288.0
# ADM_ARCHER DANIELS MIDLAND CO      560644.0    560644.0    560644.0
#
# date                             2018-12-24  2018-12-26  2018-12-27  \
# ORCL_ORACLE CORP                  3787960.0   3787960.0   3787960.0
# MSFT_MICROSOFT CORP               7676219.0   7676219.0   7676219.0
# TROW_T ROWE PRICE GROUP INC        240655.0    240655.0    240655.0
# HON_HONEYWELL INTERNATIONAL INC    740288.0    740288.0    740288.0
# ADM_ARCHER DANIELS MIDLAND CO      560644.0    560644.0    560644.0
#
# date                             2018-12-28  2018-12-31
# ORCL_ORACLE CORP                  3787960.0   3588919.0
# MSFT_MICROSOFT CORP               7676219.0   7676219.0
# TROW_T ROWE PRICE GROUP INC        240655.0    240655.0
# HON_HONEYWELL INTERNATIONAL INC    740288.0    740288.0
# ADM_ARCHER DANIELS MIDLAND CO      560644.0    560644.0
#
# [5 rows x 3021 columns]

# %% [markdown]
# ### BID/ASK SPREAD TABLE

# %%
df_spread = df_askhi - df_bidlo

# %% [markdown]
# ### MARKET CAP TABLE

# %%
df_market_cap = df_shares_out*df_price

# %% [markdown]
# ### CREATE MARKET CAP CATEGORIES BY QUINTILE BUCKETS

# %%
# print(df_market_cap['2007-01-03'].describe()['min'])
# print(df_market_cap['2007-01-03'].describe()['25%'])
# print(df_market_cap['2007-01-03'].describe()['50%'])
# print(df_market_cap['2007-01-03'].describe()['75%'])
# print(df_market_cap['2007-01-03'].describe()['max'])

# %%
# print(pd.qcut(df_market_cap['2007-01-03'], q=[0, .25, .5, .75, 1.], precision=3).value_counts())
# print(pd.qcut(df_market_cap['2010-01-04'], q=[0, .25, .5, .75, 1.], precision=3).value_counts())
# print(pd.qcut(df_market_cap['2018-12-31'], q=[0, .25, .5, .75, 1.], precision=3).value_counts())

# %%
# def assign_marketcap quintile(row):
#     temp_value = row['2007-01-03']
#     if temp_value

# %% [markdown]
# ##### GENERATE LIST OF DATAFRAMES

# %%
df_list = [df_bidlo, df_askhi, df_price, df_volume, df_returns, df_shares_out, df_spread, df_market_cap]
new_df_list = []
df_name_list = ['df_bidlo', 'df_askhi', 'df_price', 'df_volume', 'df_returns', 'df_shares_out', 'df_spread', 'df_market_cap']

# %% [markdown]
# ### There was a duplicte row value for JCI_JOHNSON CONTROLS INTL PLC, so we dropped it

# %%
for i in range(len(df_list)):
    print(df_name_list[i])
    temp_value = df_list[i].loc['JCI_JOHNSON CONTROLS INTL PLC', '2016-09-06'][1]
    df_list[i].loc['JCI_JOHNSON CONTROLS INTL PLC', '2016-09-06'] = temp_value
    
    temp_df = df_list[i].T.drop_duplicates()
    #print(temp_df.head())
    new_df_list.append(temp_df.T)

del df_list
# Out:
# df_bidlo
# df_askhi
# df_price
# df_volume
# df_returns
# df_shares_out
# df_spread
# df_market_cap

# %% [markdown]
# ### UPLOAD THE DATA INTO THE S3 BUCKET

# %% [markdown]
# ##### READ CREDENTIALS TEXT FILE
# ##### CREDENTIALS BELONG TO "capstoner" user role in AWS

# %%
import boto3
from botocore.client import Config
import os
#os.chdir('C:\\Users\\A Sua\\Documents\\AWS\\credentials')
list_of_lines = []
with open('C:\\Users\\A Sua\\Documents\\AWS\\credentials\\capstoner_key.txt') as fp:
    lines = fp.readlines()
    for line in lines:
        line = line.strip()
        list_of_lines.append(line)
    fp.close()

location = list_of_lines[0].split('=')[1]
AWS_ACCESS_KEY_ID = list_of_lines[1].split('=')[1]
AWS_SECRET_ACCESS_KEY = list_of_lines[2].split('=')[1]
BUCKET_NAME = 'capstonefiu2020-data'

# %%
@timing
def upload_PENN_to_aws():
    for i in range(len(new_df_list)):
        path_to_df = 'data\\processed\\{}.csv'.format(df_name_list[i])
        new_df_list[i].to_csv(path_to_df)
        
        ## open file
        temp_data = open(path_to_df, 'rb')
        
        ### instantiate s3 client
        s3 = boto3.resource('s3', 
                  aws_access_key_id = AWS_ACCESS_KEY_ID,
                   aws_secret_access_key=AWS_SECRET_ACCESS_KEY)
        s3.Bucket(BUCKET_NAME).put_object(Key='data/processed/{}.csv'.format(df_name_list[i]), Body=temp_data)
        
        ### close the file
        temp_data.close()
        os.remove(path_to_df)
        print('{} added to cloud'.format(df_name_list[i]))
    print('finished uploading dataframes')
    
upload_PENN_to_aws()
# Out:
# df_bidlo added to cloud
# df_askhi added to cloud
# df_price added to cloud
# df_volume added to cloud
# df_returns added to cloud
# df_shares_out added to cloud
# df_spread added to cloud
# df_market_cap added to cloud
# finished uploading dataframes
# upload_PENN_to_aws function took 126030.205 ms

# %%
# ## FROM capstoner user role
# data = open('C:\\Users\\A Sua\\Documents\\AWS\\credentials\\test_csv.csv', 'rb')

# s3 = boto3.resource('s3', 
#               aws_access_key_id = AWS_ACCESS_KEY_ID,
#                aws_secret_access_key=AWS_SECRET_ACCESS_KEY)


# s3.Bucket(BUCKET_NAME).put_object(Key='data/test_csv.csv', Body=data)

# data.close()

# %%
# for i in range(len(df_list)):
#     print(df_name_list[i])
#     print(new_df_list[i].columns.value_counts()[:2])

# %%
# df_askhi.loc['JCI_JOHNSON CONTROLS INTL PLC', '2016-09-06'] = 48.97
# df_askhi.loc['JCI_JOHNSON CONTROLS INTL PLC', '2016-09-06']

# %%
# df_askhi.T.drop_duplicates().loc['2016-09-06', 'JCI_JOHNSON CONTROLS INTL PLC']

# %%
# df_bidlo.loc['JCI_JOHNSON CONTROLS INTL PLC', '2016-09-06']
# #df_bidlo.loc['JCI_JOHNSON CONTROLS INTL PLC', '2016-09-06']

# %%
# for i in range(len(df_list)):
#     print(df_name_list[i])
#     temp_value = df_list[i].loc['JCI_JOHNSON CONTROLS INTL PLC', '2016-09-06'][1]
#     df_list[i].loc['JCI_JOHNSON CONTROLS INTL PLC', '2016-09-06'] = temp_value
    
#     temp_df = df_list[i].T.drop_duplicates()
#     #print(temp_df.head())
#     new_df_list.append(temp_df.T)

# %% [markdown]
# ### Take the error dataframe and filter out the highest RETURN highest return if >=0 else return the lowest return if <0
# - Same with return

# %% [markdown]
# ### SHARES OUTSTANDING take the HIGHEST

# %% [markdown]
# # WORKSPACE

# %% [markdown]
# #### what is the date range for the longest trading stock?

# %% [markdown]
# #### how many different company names are there?
# #### note: there is the possibility that a symbol can have multiple company names
# #### which companies lasted through the 20-year period?
# ####

# %% [markdown]
# ### each of the companies has a different number of rows
# ### so what we have to do is make a skeleton table and merge it with the original dataframe on a Left join

# %% [markdown]
# ### DONT FORGET TO ADD THE MAX SPREAD (ASK-BID)

# %% [markdown]
# ### BID TABLE

# %%
# @timing
# def bid_func():

#     error_bid = []
#     df_bid = df[['date', 'symbol', 'bid']]
#     df_bid_temp = pd.DataFrame([])
#     for symbol in list_symbol:
#         try:        
#             df_temp = df_bid[df_bid['symbol']==symbol]
#             df_temp.index=df_temp['date']
#             df_temp = df_temp[['bid']]
#             df_temp = df_temp.T
#             df_temp.index = [symbol]
#             #df_temp.rename()
#             df_bid_temp = pd.concat([df_bid_temp, df_temp], axis=0)
#         except:
#             error_bid.append(symbol)
#     return df_bid_temp, error_bid

# df_bid, error_bid = bid_func()
# print(len(error_bid))
# pd.Series(error_bid).to_csv('..\data\\error_bid.csv')
# df_bid.head(2)

# %% [markdown]
# ### ASK TABLE

# %%
# @timing
# def ask_func():
#     error_ask = []

#     df_ask = df[['date', 'symbol', 'ask']]
#     ########----------------#######
#     df_ask_temp = pd.DataFrame([])
#     for symbol in list_symbol:
#         try:            
#             df_temp = df_ask[df_ask['symbol']==symbol] ### NO _temp IN THE FILTER
#             df_temp.index=df_temp['date']
#             df_temp = df_temp[['ask']]
#             df_temp = df_temp.T
#             df_temp.index = [symbol]
#             #df_temp.rename()
#             df_ask_temp = pd.concat([df_ask_temp, df_temp], axis=0)

#         except:
#             error_ask.append(symbol)
#     return df_ask_temp, error_ask

# df_ask, error_ask = ask_func()
# print(len(error_ask))
# pd.Series(error_ask).to_csv('..\data\\error_ask.csv')
# df_ask.head(2)

# %% [markdown]
# ### OPEN PRICE TABLE

# %%
# @timing
# def open_func():
#     error_open = []
#     df_open = df[['date', 'symbol', 'open']]
#     ########----------------#######
#     df_open_temp = pd.DataFrame([])
#     for symbol in list_symbol:
#         try:            
#             df_temp = df_open[df_open['symbol']==symbol] ### NO _temp IN THE FILTER
#             df_temp.index=df_temp['date']
#             df_temp = df_temp[['open']] 
#             df_temp = df_temp.T
#             df_temp.index = [symbol]
#             #df_temp.rename()
#             df_open_temp = pd.concat([df_open_temp, df_temp], axis=0) ### TEM
#         except:
#             error_open.append(symbol)
#     return df_open_temp, error_open

# df_open, error_open = open_func()
# print(len(error_open))
# pd.Series(error_open).to_csv('..\data\\error_open.csv')
# df_open.head(2)

# %%
# df_askhi.T.index.value_counts().to_csv('data\\external\\temp_dates.csv')

# %%
# df_merge['date'].value_counts().to_csv('data\\external\\temp_dates.csv')
