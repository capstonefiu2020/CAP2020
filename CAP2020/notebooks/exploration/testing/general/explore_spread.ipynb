# %% [markdown]
# #### EXPLORE SPREAD

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import boto3
from botocore.client import Config
import os
import pandas as pd
from io import StringIO
import matplotlib.dates as dates
from datetime import datetime
import matplotlib.ticker as ticker

os.chdir('C:\\Users\\A Sua\\Documents\\AWS\\credentials')
list_of_lines = []
with open('capstoner_key.txt') as fp:
    lines = fp.readlines()
    for line in lines:
        line = line.strip()
        list_of_lines.append(line)
    fp.close()


location = list_of_lines[0].split('=')[1]
AWS_ACCESS_KEY_ID = list_of_lines[1].split('=')[1]
AWS_SECRET_ACCESS_KEY = list_of_lines[2].split('=')[1]
os.chdir('C:\\Users\\A Sua\\Documents\\FIU\\CAP2020')

# %% [markdown]
# ### IMPORT SPREAD

# %%
### BUCKETS & KEYS
BUCKET_NAME = 'capstonefiu2020-data'
key_location = 'data/processed'
file_name = 'df_spread.csv'
key_path = key_location + '/' + file_name

### ACTIVATE CLIENT
client = boto3.client('s3', 
              aws_access_key_id = AWS_ACCESS_KEY_ID,
               aws_secret_access_key=AWS_SECRET_ACCESS_KEY)


### INSTANTIATE DATAFRAME
csv_obj = client.get_object(Bucket = BUCKET_NAME, Key=key_path)
body = csv_obj['Body']
csv_string = body.read().decode('utf-8')

df_spread = pd.read_csv(StringIO(csv_string))
df_spread.index = df_spread['Unnamed: 0']
df_spread = df_spread.drop('Unnamed: 0', axis=1)
df_spread.index.names = ['date']


#df_bidlo.head()
#### TRANSPOSE DATA FOR EASE OF USE
df_spread = df_spread.T
df_spread.index = pd.to_datetime(df_spread.index)
df_spread.head()
# Out:
# date        ORCL_ORACLE CORP  MSFT_MICROSOFT CORP  \
# 2000-01-03           13.5625               6.6250
# 2000-01-04           13.6250               4.8750
# 2000-01-05           10.3750               7.0000
# 2000-01-06           10.3125               5.5000
# 2000-01-07            9.9375               4.9375
#
# date        TROW_T ROWE PRICE GROUP INC  HON_HONEYWELL INTERNATIONAL INC  \
# 2000-01-03                        2.625                           2.0000
# 2000-01-04                        1.125                           2.3750
# 2000-01-05                        1.750                           1.5625
# 2000-01-06                        1.625                           1.6250
# 2000-01-07                        1.000                           2.9375
#
# date        T_A T & T CORP  ADM_ARCHER DANIELS MIDLAND CO  \
# 2000-01-03          2.8750                         0.1875
# 2000-01-04          2.0000                         0.3750
# 2000-01-05          1.7500                         0.2500
# 2000-01-06          3.3125                         0.3125
# 2000-01-07          2.0625                         0.1875
#
# date        FRC_FIRST REPUBLIC BANK S F  FISV_FISERV INC  \
# 2000-01-03                       0.8125           1.3125
# 2000-01-04                       1.0000           3.2500
# 2000-01-05                       0.4375           3.0000
# 2000-01-06                       0.3750           1.8125
# 2000-01-07                       0.6875           2.2500
#
# date        CF_CHARTER ONE FINANCIAL INC  \
# 2000-01-03                        1.3125
# 2000-01-04                        1.0000
# 2000-01-05                        0.9375
# 2000-01-06                        1.1250
# 2000-01-07                        0.8125
#
# date        PHBK_PEOPLES HERITAGE FINL GROUP INC  ...  CDB_CANANDAIGUA BRANDS  \
# 2000-01-03                                1.2500  ...                  8.1250
# 2000-01-04                                0.4375  ...                  9.0625
# 2000-01-05                                0.2500  ...                  9.2500
# 2000-01-06                                0.5000  ...                  6.9375
# 2000-01-07                                0.3750  ...                  4.5000
#
# date        STZ_CONSTELLATION BRANDS INC  VIA_VIACOM INC  \
# 2000-01-03                           NaN          3.8125
# 2000-01-04                           NaN          3.3750
# 2000-01-05                           NaN          3.2500
# 2000-01-06                           NaN          1.6875
# 2000-01-07                           NaN          3.3750
#
# date        FCX_FREEPORT MCMORAN INC  IT_GARTNER INC  PLD_PROLOGIS TRUST  \
# 2000-01-03                    3.1875          2.8750              0.8125
# 2000-01-04                    3.6250          2.7500              0.7500
# 2000-01-05                    3.4375          2.5000              0.6875
# 2000-01-06                    3.4375          2.5625              0.3125
# 2000-01-07                    3.1875          3.1250              0.1875
#
# date        DVA_DAVITA  TAP_TRAVELERS PPTY CASUALTY CORP  V_VIVENDI UNIVERSAL  \
# 2000-01-03         NaN                            1.8750                  NaN
# 2000-01-04         NaN                            0.9375                  NaN
# 2000-01-05         NaN                            1.0625                  NaN
# 2000-01-06         NaN                            1.0625                  NaN
# 2000-01-07         NaN                            1.0000                  NaN
#
# date        CMG_CHIPOTLE MEXICAN GRILL INC
# 2000-01-03                             NaN
# 2000-01-04                             NaN
# 2000-01-05                             NaN
# 2000-01-06                             NaN
# 2000-01-07                             NaN
#
# [5 rows x 712 columns]

# %% [markdown]
# ### import price

# %%
### BUCKETS & KEYS
BUCKET_NAME = 'capstonefiu2020-data'
key_location = 'data/processed'
file_name = 'df_price.csv'
key_path = key_location + '/' + file_name

### ACTIVATE CLIENT
client = boto3.client('s3', 
              aws_access_key_id = AWS_ACCESS_KEY_ID,
               aws_secret_access_key=AWS_SECRET_ACCESS_KEY)


### INSTANTIATE DATAFRAME
csv_obj = client.get_object(Bucket = BUCKET_NAME, Key=key_path)
body = csv_obj['Body']
csv_string = body.read().decode('utf-8')

df_price = pd.read_csv(StringIO(csv_string))
df_price.index = df_price['Unnamed: 0']
df_price = df_price.drop('Unnamed: 0', axis=1)
df_price.index.names = ['date']


#df_bidlo.head()
#### TRANSPOSE DATA FOR EASE OF USE
df_price = df_price.T
df_price.index = pd.to_datetime(df_price.index)
df_price.head()
# Out:
# date        ORCL_ORACLE CORP  MSFT_MICROSOFT CORP  \
# 2000-01-03          118.1250             116.5625
# 2000-01-04          107.6875             112.6250
# 2000-01-05          102.0000             113.8125
# 2000-01-06           96.0000             110.0000
# 2000-01-07          103.3750             111.4375
#
# date        TROW_T ROWE PRICE GROUP INC  HON_HONEYWELL INTERNATIONAL INC  \
# 2000-01-03                      35.1250                          56.6875
# 2000-01-04                      34.0625                          55.6875
# 2000-01-05                      34.0000                          54.9375
# 2000-01-06                      35.0000                          56.0000
# 2000-01-07                      34.7500                          59.0000
#
# date        T_A T & T CORP  ADM_ARCHER DANIELS MIDLAND CO  \
# 2000-01-03         53.3750                        12.0000
# 2000-01-04         51.2500                        11.8750
# 2000-01-05         50.9375                        11.6875
# 2000-01-06         48.5000                        11.7500
# 2000-01-07         49.0000                        11.9375
#
# date        FRC_FIRST REPUBLIC BANK S F  FISV_FISERV INC  \
# 2000-01-03                       22.625         38.12500
# 2000-01-04                       21.500         35.50000
# 2000-01-05                       21.125         37.96875
# 2000-01-06                       21.375         36.78125
# 2000-01-07                       22.125         38.15625
#
# date        CF_CHARTER ONE FINANCIAL INC  \
# 2000-01-03                        18.250
# 2000-01-04                        17.500
# 2000-01-05                        17.875
# 2000-01-06                        17.500
# 2000-01-07                        17.625
#
# date        PHBK_PEOPLES HERITAGE FINL GROUP INC  ...  CDB_CANANDAIGUA BRANDS  \
# 2000-01-03                               14.1250  ...                  56.375
# 2000-01-04                               13.9375  ...                  56.375
# 2000-01-05                               14.0000  ...                  56.500
# 2000-01-06                               14.0000  ...                  56.500
# 2000-01-07                               14.3125  ...                  56.250
#
# date        STZ_CONSTELLATION BRANDS INC  VIA_VIACOM INC  \
# 2000-01-03                           NaN         60.6875
# 2000-01-04                           NaN         57.0000
# 2000-01-05                           NaN         54.2500
# 2000-01-06                           NaN         51.4375
# 2000-01-07                           NaN         54.1250
#
# date        FCX_FREEPORT MCMORAN INC  IT_GARTNER INC  PLD_PROLOGIS TRUST  \
# 2000-01-03                   21.4375          16.625             19.2500
# 2000-01-04                   21.0000          16.125             19.0625
# 2000-01-05                   20.8125          15.375             19.1250
# 2000-01-06                   20.9375          14.875             19.3125
# 2000-01-07                   20.5000          15.250             19.3750
#
# date        DVA_DAVITA  TAP_TRAVELERS PPTY CASUALTY CORP  V_VIVENDI UNIVERSAL  \
# 2000-01-03         NaN                           35.1250                  NaN
# 2000-01-04         NaN                           33.4375                  NaN
# 2000-01-05         NaN                           34.2500                  NaN
# 2000-01-06         NaN                           35.2500                  NaN
# 2000-01-07         NaN                           35.9375                  NaN
#
# date        CMG_CHIPOTLE MEXICAN GRILL INC
# 2000-01-03                             NaN
# 2000-01-04                             NaN
# 2000-01-05                             NaN
# 2000-01-06                             NaN
# 2000-01-07                             NaN
#
# [5 rows x 712 columns]

# %% [markdown]
# ### create the spread/price

# %%
df_spread_price = df_spread/df_price

# %% [markdown]
# ## NOW THAT I THINK OF IT, A MORE IMPORTANT METRIC WOULD BE SPREAD / STOCKPRICE
# ### ALSO CALLED RELATIVE SPREAD

# %%
key_list = df_spread.columns

for company in key_list[:20]:
    fig, ax = plt.subplots()
    ax.hist(df_spread_price[company])
    #ax.plot(df_askhi[company])
    plt.xticks(rotation=45)
    plt.xlim(0, 0.5)
    plt.title('{}:\nSpread Histogram: 2000-2019'.format(company), fontsize=15)
    plt.show()
    print('')
    print('')
# Out:
# C:\PROGRA1\Anaconda3\lib\site-packages\numpy\lib\histograms.py:829: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# C:\PROGRA1\Anaconda3\lib\site-packages\numpy\lib\histograms.py:830: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)
